# %%
import nest_asyncio

# %%
nest_asyncio.apply()

# %%
import torch
import syft

# %%
from syft import WebsocketServerWorker

# %%
hook = syft.TorchHook(torch)

# %%
local_worker = WebsocketServerWorker(host="localhost",hook=hook,id="alice",port=8182,log_msgs=True,verbose=True)

# %%
local_worker.start()
# Out:
# Serving. Press CTRL-C to stop.
# worker <WebsocketServerWorker id:alice #objects:0> received ObjectMessage tensor([[5.1000, 3.5000, 1.4000, 0.2000],
#         [6.7000, 2.5000, 5.8000, 1.8000],
#         [4.9000, 2.5000, 4.5000, 1.7000],
#         [6.0000, 3.4000, 4.5000, 1.6000],
#         [6.3000, 2.9000, 5.6000, 1.8000],
#         [6.9000, 3.1000, 5.4000, 2.1000],
#         [5.0000, 2.0000, 3.5000, 1.0000],
#         [5.4000, 3.9000, 1.7000, 0.4000]])
# worker <WebsocketServerWorker id:alice #objects:1> received ObjectMessage tensor([0., 2., 2., 1., 2., 2., 1., 0.])
# worker <WebsocketServerWorker id:alice #objects:2> received ObjectMessage tensor([[6.2000, 3.4000, 5.4000, 2.3000],
#         [6.9000, 3.1000, 4.9000, 1.5000],
#         [4.9000, 3.0000, 1.4000, 0.2000],
#         [6.1000, 2.8000, 4.7000, 1.2000],
#         [6.7000, 3.1000, 5.6000, 2.4000],
#         [4.9000, 3.6000, 1.4000, 0.1000],
#         [5.0000, 3.6000, 1.4000, 0.2000],
# ...

# %%
local_worker.list_objects()
