# %%
import nest_asyncio

# %%
nest_asyncio.apply()

# %%
import torch
import syft

# %%
from syft import WebsocketServerWorker

# %%
hook = syft.TorchHook(torch)

# %%
local_worker = WebsocketServerWorker(host="localhost",hook=hook,id="bob",port=8183,log_msgs=True,verbose=True)

# %%
local_worker.start()
# Out:
# Serving. Press CTRL-C to stop.
# worker <WebsocketServerWorker id:bob #objects:0> received ObjectMessage tensor([[4.8000, 3.4000, 1.9000, 0.2000],
#         [5.7000, 2.8000, 4.1000, 1.3000],
#         [5.5000, 2.3000, 4.0000, 1.3000],
#         [5.7000, 2.6000, 3.5000, 1.0000],
#         [7.7000, 3.8000, 6.7000, 2.2000],
#         [6.4000, 2.7000, 5.3000, 1.9000],
#         [5.9000, 3.0000, 5.1000, 1.8000],
#         [4.7000, 3.2000, 1.6000, 0.2000]])
# worker <WebsocketServerWorker id:bob #objects:1> received ObjectMessage tensor([0., 1., 1., 1., 2., 2., 2., 0.])
# worker <WebsocketServerWorker id:bob #objects:2> received ObjectMessage tensor([[4.4000, 2.9000, 1.4000, 0.2000],
#         [7.1000, 3.0000, 5.9000, 2.1000],
#         [5.7000, 2.9000, 4.2000, 1.3000],
#         [5.4000, 3.0000, 4.5000, 1.5000],
#         [6.5000, 3.0000, 5.5000, 1.8000],
#         [4.6000, 3.1000, 1.5000, 0.2000],
#         [5.5000, 4.2000, 1.4000, 0.2000],
#         [6.4000, 2.8000, 5.6000, 2.1000]])
# ...
